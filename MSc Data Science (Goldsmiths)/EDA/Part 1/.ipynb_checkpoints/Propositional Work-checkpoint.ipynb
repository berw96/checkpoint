# %% [markdown]
# <h1>IS71068A Data Programming (2022)</h1>
# <h2>Coursework 1</h2>

# %% [markdown]
# <h3>Mr Elliot Walker</h3>
# <h3>PT MSc Data Science</h3>
# <h3>ID: 3368 6408</h3>

# %% [markdown]
# <h2>Overview</h2>
# <h3>The Project</h3>
# <p align = "justify">This project is about the effects of the <b>Russo-Ukrainian War</b> on both Russia and <b>NATO</b>'s defense budgets, and gas prices throughout the European Continent. In particular, it pertains to the repercussions NATO's defense budget has on Europeans as a result of their historic dependence on Russian gas exports.</p>
#
# <h3>Russo-Ukrainian War</h3>
# <p align = "justify">On February 24th 2022, forces from the <b>Russian Federation</b> invaded <b>The Ukraine</b> from its Eastern borders. In the months following, four oblasts (regions) - <b>Donestk</b>, <b>Kherson</b>, <b>Luhansk</b> and <b>Zaporizhzhia</b> - were formally annexed and absorbed, along with <b>Crimea</b> (annexed 2014), into the Russian Federation. Although, this annexation of Ukrainian territory remains unrecognized by the international community, spare North Korea.</p>
#
# <p align = "justify">Below is a summary of key events which have occured since the begining of the war.
#
# <ul>
#     <li>Origins
#         <ul>
#             <li>20/02/2014 - Russia invades Crimea</li>
#             <li>18/03/2014 - Russia annexes Crimea</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>Build-up
#         <ul>
#             <li>03/03/2021 to 26/10/2021 - Build-up of Russian forces along the Ukrainian border</li>
#             <li>21/02/2022 - Donetsk and Luhansk are formally recognized as independent states by Russia</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>Invasion
#         <ul>
#             <li>24/02/2022 - A full-scale invasion is launched against Ukraine by Russia</li>
#             <li>30/09/2022 - Russia claims/annexes four regions of Eastern Ukraine</li>
#         </ul>
#     </li>
# </ul>
# <ul>
#     <li>Ongoing...
#         <ul>
#             <li>26/10/2022 - NATO and Russia conducting nuclear drills</li>
#             <li>29/10/2022 - Russia withdraws from UN deal to protect grain exports from Ukraine</li>
#             <li>02/11/2022 - Russia re-enters UN grain export deal</li>
#         </ul>
#     </li>
# </ul>
# </p>
#
# <p align = "justify">Ongoing, the Russo-Ukrainian War is the greatest conflict on European soil since the Second World War (which involved the <b>United States</b>, the <b>British Empire</b> and the <b>Soviet Union</b> against <b>National Socialist (Nazi) Germany</b> and <b>Fascist Italy</b>), with this status stirring deepened concerns from the Western forces of NATO and allies.</p>
#
# <h3>Nord Stream 1 & 2</h3>
# <p align = "justify">European dependence on Russian natural gas was facilitated by the pipelines <b>Nord Stream 1</b> and <b>Nord Stream 2</b>, which were shut down and subsequently severely comprimised by suspected saboteurs (now assumed by Russia to have been the British Royal Navy [5]). As a consequence of gas from Russia being cut completely, gas prices in Europe have increased significantly.</p>
#
# <h3>Russia-NATO tensions</h3>
# <p align = "justify">The North Atalantic Trade Organisation or NATO was founded in the light of WW2 in April of 1949 as an oppositional alliance between the Western nations - of democratic, capitalist orientation - and the Eastern nations (including Russia) of authortarian, socialist/communist orientation. The Soviet Union had annexed all of Eastern Europe, including East Germany (then the German Democratic Republic), and it was NATO that was formed to monitor and decelerate any attempts by the Soviets to further expand their influence to the West. The equivalent to NATO for the Eastern bloc was the <b>Warsaw Pact</b>, formed by the USSR, Poland, Bulgaria, Hungary, Romania, Albania, East Germany, and Czechoslovakia.</p>
#
# <p align = "justify">Throughout the Cold War (1947-1991) and up until today, tensions have remained consistent between the two ideologies, and for nearly a decade since 2014 Crimean War these tensions have been particularly present between Russia and NATO (with the USA spearheading the organisation's stance in the world). The tensions are partly geopolitical, stemming from the presence of NATO in the EU and former USSR states (Ukraine, Belarus, Latvia, Estonia, etc), and Russia's assaults on Ukraine. It is these tensions which serve as ground to explore correlation between the two side's military budgets, and the energy prices in Europe which have risen significantly due to Russian sanctions.</p>
#
# <p align = "justify">Russia is largely invulnerable as far as invasion goes - it is surrounded by artic sheilds to the North and East, and both mountainous ranges and allies to the South, making the act of ground invasion largely impractical. However, there exists a small corridor to its West which leads all the way into the capital Moscow, known as the <b>East European Plain</b>. Russian incentive to annex or gain significant influence in East Europe centers around this geography - they want buffer states to prevent or hinder invasion from the West. Hence, the attempts of Ukraine - which lies on Russia's doorstep - to edge closer to the influence of the West (European Union and NATO) stirs concern in Russia. The invasion of Ukraine is partly justified by Russian officials due to the history which Ukraine shares with Russia, with the latter claiming the former as a long lost sibling.</p>

# %% [markdown]
# <h2>Problem Area</h2>
# <h3>Economic Polemology</h3>
# <p align = "justify"><b>Polemology</b> is the study of warfare, and this project focuses on the economic factors arising from observations in the Russo-Ukrainian War, and how fluctuating tensions between Russia and NATO influence these observations.</p>
#
# <h3>Question</h3>
# <p align = "justify">What correlations exist (if any) between the following observations from <b>January 2021</b>?:</p>
# <ul>
#     <li>NATO defense expenditure</li>
#     <li>Russian defense expenditure</li>
#     <li>European gas prices</li>
# </ul>
#
# <p align = "justify">Provided correlation exists between one or more pairings for these data sets, a regressional model could be developed to better generalize their relationship. Additionally, these findings would be basis for further research into the economic effects of the war on a wider scale (e.g., how does gas price effect home economics for families across Europe?).</p>
#
# <p align = "justify">The expectation is that there should exist <i>some form of correlation</i> between these three data sets. European gas prices are affected by the war in Ukraine, which is related to Russia's military presence (and thus expenditure), which in turn arises from its mutually negative status with NATO and its military spending.</p>

# %% [markdown]
# <h1>Methods</h1>
#
# <h3>Exploratory Data Analysis</h3>
# <p align = "justify"><b>Exploratory Data Analysis (EDA)</b> involves the high-level summary of data. This includes the following:</p>
#
# <ul>
#     <li>creating visualizations for the data sets</li>
#     <li>summarising key aspects (e.g., central tendencies, standard deviation)</li>
#     <li>drawing relationships between observations and response variables</li>
#     <li>establishing a basis for deeper analysis</li>
# </ul>
#
# <p align = "justify">Visualization, <b>central tendency</b> (e.g., arithmetic mean, median, mode), and <b>standard deviation</b> are crucial to EDA as they effectively and succinctly communicate data, in one image or value. Visualization enables us to observe trends and distributions in data sets. Central tendency provides insight to the value(s) which are representative of our data. Standard deviation signals to us how much stochastic observations deviate from an established central tendency (specifically the arithmetic mean).</p>
#
# <h3>Standard Deviation</h3>
# <p align = "justify">The standard deviation ($\sigma$) of a data set measures the dispertion of values relative to its arithmetic mean. Equal to the square root of <b>variance</b>, the standard deviation of a set of values is given by:</p>
#
# $$\sigma = \sqrt{\frac{\sum_{i=1}^{i=n}(x_{i}-\mu)^{2}}{n}}$$
#
# <p align = "justify">where $\mu$ is the population mean of the data set, which contains $n$ observed values.</p>
#
# <h3>Correlation</h3>
# <p align = "justify">The correlation between two stochastic variables measures how they affect each other. Correlation may be non-existent ($0$), positive ($+ve$), such that the two variables trend with a positive gradient, or negative ($-ve$), such that the two variables trend with a negative gradient. The correlation is seldom perfect (magnitude 1), and in instances where it is perfect, suspicion should be raised as to the viability of the data used.</p>
#
# <p align = "justify">For continuous, regressional data, it is required that said data be <b>normalized</b> before any correlations can be drawn. Normalized data adheres to a frequency distribution of values close to its second quartile (central tendency), and exhibits little to no <b>skewness</b>.</p>
#
# <p align = "justify">For linear models, we use the <b>Pearson Correlation Coefficient</b>, given by the following expression:</p>
#
# $$r_{xy} = \frac{n\sum_{i=1}^{i=n}x_{i}y_{i} - \sum_{i=1}^{i=n}x_{i}\sum_{i=1}^{i=n}y_{i}}{\sqrt{n\sum_{i=1}^{i=n}x_{i}^{2} - (\sum_{i=1}^{i=n}x_{i})^{2}}\sqrt{n\sum_{i=1}^{i=n}y_{i}^{2}-(\sum_{i=1}^{i=n}y_{i})^{2}}}$$
#
# <p align = "justify">which measures the correlation (mutual effect) between a given input $x_{i}$ and its corresponding output $y_{i}$, for $n$ observations in the provided data set.</p>
#
# <h3>Skewness</h3>
# <p align = "justify">Skewness measures the imbalance of a dataset from being normally distributed. A Gaussian distribution exhibiting a (near) perfect bell curve when plotted would possess zero skewness, for instance. Skewness may be either positive ($+ve$) wherein the tail of the dataset is longer on the right, or negative ($-ve$) wherein it is longer on the left.</p>
#
# <p align = "justify"><b>Galton Skewness</b> (AKA <b>Bowley's Skewness</b>) considers the upper and lower quartiles ($Q_1$ and $Q_3$) and the median ($Q_2$) of the dataset:</p>
#
# $$GS := \frac{Q_1 + Q_3 - 2Q_2}{Q_3 - Q_1}$$
#
# <h3>Python Libraries</h3>
# <p align = "justify">The <b>Pandas</b> and <b>Numpy</b> libraries are used throughout the analysis involved in this project. Pandas provides convenient means of reading data from a CSV (Comma Separated Value) file into an entity known as a <b>data frame</b>, which serves to organize the data in a tabular format, and it additionally provides functions suitable for EDA (e.g., plotting, correlation, standard deviation, central tendencies). Numpy is utilized for calculating the arithmetic mean of data columns, which is useful for succinctly describing a range of observations with one value.</p>

# %% [markdown]
# <h2>Analysis of Data</h2>
#
# <h3>NATO and Russian Military Expenditures</h3>
# <p align = "justify">Data for NATO defense spending across all member nations is provided courtesy of NATO itself [1], whereas the data pertaining to Russia's defense spending is not entirely available. The Russian budget [2] is provided as an informed estimate courtesy of the <b>Stockholm International Peace Research Instutute (SIPRI)</b>, which abides by NATO's standards of which resources contribute to military spending:</p>
#
# <ul>
#     <li>Peacekeeping forces</li>
#     <li>Paramilitary</li>
#     <li>Military research</li>
#     <li>Development</li>
#     <li>Aid</li>
#     <li>Maintenance</li>
#     <li>Space operations</li>
# </ul>
#
# <p align = "justify">Data for NATO expenditure is given below:</p>

# %%
import pandas as pd

NATO_budget_CSV_path = "datasets/NATO_military_budget_by_billion_dollars.csv"

try:
    with open(NATO_budget_CSV_path, mode = "r") as f:
        NATO_budget_df = pd.read_csv(f)
        
        # Console output
        print("\nOverview:")
        print(NATO_budget_df)
        print("\nCorrelation matrix:")
        print(NATO_budget_df.corr())
        print("\nSkewness of Cost:")
        print(NATO_budget_df["Cost"].skew())
        
        # Plots
        NATO_budget_df.plot.line(x = "Year", y = "Cost", title = "NATO military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
        NATO_budget_df.plot.bar(x = "Year", y = "Cost", title = "NATO military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
        NATO_budget_df.plot.hist(x = "Year", title = "Frequency distribution of NATO military expenditure (2014-2022)", figsize=(10,5)).set_xlabel("USD (Bn)")
        
except FileNotFoundError:
    print("Could not find file: " + NATO_budget_CSV_path)
    print("Check path spelling or directory contents.")
# Out:
# Overview:
#    Year         Cost
# 0  2014   943.217299
# 1  2015   895.675846
# 2  2016   911.653708
# 3  2017   918.033053
# 4  2018   972.422445
# 5  2019  1052.560913
# 6  2020  1096.594001
# 7  2021  1155.279595
# 8  2022  1189.875017
#
# Correlation matrix:
#           Year      Cost
# Year  1.000000  0.928452
# Cost  0.928452  1.000000
#
# Skewness of Cost:
# 0.5242721910545268

# %% [markdown]
# <p align = "justify">Data for Russian Expenditure is given below:</p>

# %%
import pandas as pd

RUS_budget_CSV_path = "datasets/Russia_military_budget_by_billion_dollars.csv"

try:
    with open(RUS_budget_CSV_path, mode = "r") as f:
        RUS_budget_df = pd.read_csv(f)
        
        # Console output
        print("\nOverview:")
        print(RUS_budget_df)
        print("\nCorrelation matrix:")
        print(RUS_budget_df.corr())
        print("\nSkewness of Cost:")
        print(RUS_budget_df["Cost"].skew())
        
except FileNotFoundError:
    print("Could not find file: " + RUS_budget_CSV_path)
    print("Check path spelling or directory contents.")
# Out:
# Overview:
#    Year   Cost
# 0  2014  84.70
# 1  2015  66.42
# 2  2016  69.25
# 3  2017  66.91
# 4  2018  61.61
# 5  2019  65.20
# 6  2020  61.71
# 7  2021  65.91
# 8  2022  90.90
#
# Correlation matrix:
#           Year      Cost
# Year  1.000000  0.028627
# Cost  0.028627  1.000000
#
# Skewness of Cost:
# 1.4787649044219509

# %% [markdown]
# <div class="alert alert-block alert-info">
# <p align = "justify">The Russian government has not released any data on its military spending since May 2022, and thus official figures are unavailable for analysis. It is expected, though, that due to the trend this budget has followed since the Crimean conflict, it may very well be equal to or greater than the most recent record released [4].</p>
# </div>
#
# <p align = "justify">According to [4] and [6], the initial Russian defence budget for 2022 was approximately 63.6Bn USD, although in light of the war this can very well vary, with the greatest estimate being 90.9Bn USD by the end of 2022. Below we apply the latter estimate of £90.9Bn as a reasonable assumption for the 2022 defense budget of Russia. At the time of writing it is currently not possible to access [6] via browser or webscraping, perhaps due to regional restrictions.</p>

# %%
# Plots
RUS_budget_df.plot.line(x = "Year", y = "Cost", title = "Russian military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
RUS_budget_df.plot.bar(x = "Year", y = "Cost", title = "Russian military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
RUS_budget_df.plot.hist(x = "Year", title = "Frequency distribution of Russian military expenditure (2014-2022)", figsize=(10,5)).set_xlabel("USD (Bn)")
# Out:
#           Year      Cost
# Year  1.000000  0.028627
# Cost  0.028627  1.000000

# %% [markdown]
# <p align = "justify">Plotted together, we can compare the Russia's and NATO's military budgets:</p>

# %%
import pandas as pd

# A single CSV file containing both NATO and Russia's defense budgets from 2014 to 2022
Compared_budgets_CSV_path = "datasets/Compared_military_budgets_by_billion_dollars.csv"

try:
    with open(Compared_budgets_CSV_path, mode = "r") as f:
        comparison_df = pd.read_csv(f)
        
        # Console output
        print("\nOverview:")
        print(comparison_df)
        print("\nCorrelation matrix:")
        print(comparison_df.corr())
        
        # Plots
        comparison_df.plot.line(x = "Year", y = ["Russian Budget", "NATO Budget"], title = "Russian vs NATO military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
        comparison_df.plot.bar(x = "Year", y = ["Russian Budget", "NATO Budget"], title = "Russian vs NATO military expenditure (2014 - 2022)", figsize=(10,5)).set_ylabel("USD (Bn)")
        
except FileNotFoundError:
    print("Could not find file: " + Compared_budgets_CSV_path)
    print("Check path spelling or directory contents.")
# Out:
#    Year  Russian Budget  NATO Budget
# 0  2014           84.70   943.217299
# 1  2015           66.42   895.675846
# 2  2016           69.25   911.653708
# 3  2017           66.91   918.033053
# 4  2018           61.61   972.422445
# 5  2019           65.20  1052.560913
# 6  2020           61.71  1096.594001
# 7  2021           65.91  1155.279595
# 8  2022           90.90  1189.875017
#                     Year  Russian Budget  NATO Budget
# Year            1.000000        0.028627     0.928452
# Russian Budget  0.028627        1.000000     0.252699
# NATO Budget     0.928452        0.252699     1.000000

# %% [markdown]
# <p align = "justify">Summary of NATO budget</p>

# %%
print(comparison_df["NATO Budget"].describe())
# Out:
# count       9.000000
# mean     1015.034653
# std       111.587932
# min       895.675846
# 25%       918.033053
# 50%       972.422445
# 75%      1096.594001
# max      1189.875017
# Name: NATO Budget, dtype: float64

# %% [markdown]
# <p align = "justify">Summary of Russian budget</p>

# %%
print(comparison_df["Russian Budget"].describe())
# Out:
# count     9.000000
# mean     70.290000
# std      10.331713
# min      61.610000
# 25%      65.200000
# 50%      66.420000
# 75%      69.250000
# max      90.900000
# Name: Russian Budget, dtype: float64

# %% [markdown]
# <p align = "justify">The correlation between the NATO and Russian budgets are given as follows:</p>

# %%
print("Correlation: " + str(comparison_df["NATO Budget"].corr(comparison_df["Russian Budget"])))
# Out:
# Correlation: 0.2526993162419751

# %% [markdown]
# <p align = "justify">This implies that the two budgets share a <b>weak positive correlation</b>: where Russia's budget increases relatively slightly, NATO's budget increases greatly.</p>
#
# <p align = "justify">Although, care must be taken not to infer causation from this. Correlation is <i>not</i> causation.</p>

# %% [markdown]
# <p align = "justify">Below is a bar chart visualizing how the average defense budgets of NATO and Russia compare.</p>

# %%
import numpy as npy

average_RUS_budget = npy.mean(RUS_budget_df["Cost"])
average_NATO_budget = npy.mean(NATO_budget_df["Cost"])
    
average_budgets = {"NATO" : [average_NATO_budget],
                    "Russia" : [average_RUS_budget]}
    
average_budgets_df = pd.DataFrame(average_budgets)
average_budgets_df.plot.barh(y = ["Russia", "NATO"], title = "Russian vs NATO average military expenditure (2014 - 2022)", figsize=(10,5)).set_xlabel("USD (Bn)")
# Out:
# Text(0.5, 0, 'USD (Bn)')

# %% [markdown]
# <h3>European TTF Gas Prices</h3>
# <p align = "justify">Reference is paid to the European TTF (AKA, Dutch Title Transfer Facility), which acts as a benchmark proxy for historic and present natural gas prices across the European Union (EU). Prices are stated in Euros per Megawatt-hours (how much it costs to run a megawatt for a single hour).</p>
#
# <p align = "justify">The data set for these prices was acquired through [3], and comprises of monthly records from November 2017 up until October 2022.</p>

# %%
import pandas as pd
import numpy as npy

Gas_prices_CSV_path = "datasets/Dutch_TTF_gas_prices.csv"

try:
    with open(Gas_prices_CSV_path, mode = "r") as f:
        ttf_gas_df = pd.read_csv(f, keep_default_na = False)
        
        # Console output
        print("\nOverview:")
        print(ttf_gas_df)
        print("\nCorrelation matrix:")
        print(ttf_gas_df.corr())
        print("\nSkewness of Cost:")
        print(ttf_gas_df["Cost"].skew())
        
        # Plots
        ttf_gas_df.plot.line(x = "Date", y = "Cost", title = "TTF gas prices since November 2017 in Euros per MWh", figsize=(10,5)).set_ylabel("Euros/MWh")
        
except FileNotFoundError:
    print("Could not find file: " + Gas_prices_CSV_path)
    print("Check path spelling or directory contents.")
# Out:
# Overview:
#           Date     Cost     Open     High      Low    Vol. Change %
# 0   01/11/2017   20.305   20.305   20.305   20.305           11.05%
# 1   01/12/2017   19.620   19.620   19.620   19.620           -3.37%
# 2   01/01/2018   17.880   17.880   17.880   17.880           -8.87%
# 3   01/02/2018   17.350   17.350   17.350   17.350           -2.96%
# 4   01/03/2018   18.225   18.225   18.225   18.225   0.18K    5.04%
# 5   01/04/2018   20.560   19.520   19.835   19.520   0.07K   12.81%
# 6   01/05/2018   22.580   21.135   22.260   20.840   0.09K    9.82%
# 7   01/06/2018   21.875   21.630   21.630   21.630   0.04K   -3.12%
# 8   01/07/2018   22.115   22.300   22.300   22.300   0.02K    1.10%
# 9   01/08/2018   25.835   22.000   26.025   22.000   0.22K   16.82%
# 10  01/09/2018   27.330   26.965   29.560   26.655   0.94K    5.79%
# 11  01/10/2018   24.335   26.735   27.860   25.625   0.12K  -10.96%
# 12  01/11/2018   24.690   23.975   26.725   23.625   0.59K    1.46%
# ...

# %%
# create a new dictionary for containing average gas prices per year
yearly_ttf_gas_data = {"Year":["2017", "2018", "2019", "2020", "2021", "2022"],
                        "Average Cost":[]}
    
# empty containers for average prices of gas for each year
listof_2017_prices = []
listof_2018_prices = []
listof_2019_prices = []
listof_2020_prices = []
listof_2021_prices = []
listof_2022_prices = []
    
# iterate through the contents of the data frame
for i in range(len(ttf_gas_df)):
    date = ttf_gas_df.iloc[i]["Date"]
    if(date.__contains__("2017")):
        listof_2017_prices.append(ttf_gas_df.iloc[i]["Cost"])
    elif(date.__contains__("2018")):
        listof_2018_prices.append(ttf_gas_df.iloc[i]["Cost"])
    elif(date.__contains__("2019")):
        listof_2019_prices.append(ttf_gas_df.iloc[i]["Cost"])
    elif(date.__contains__("2020")):
        listof_2020_prices.append(ttf_gas_df.iloc[i]["Cost"])
    elif(date.__contains__("2021")):
        listof_2021_prices.append(ttf_gas_df.iloc[i]["Cost"])
    elif(date.__contains__("2022")):
        listof_2022_prices.append(ttf_gas_df.iloc[i]["Cost"])
    
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2017_prices))
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2018_prices))
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2019_prices))
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2020_prices))
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2021_prices))
yearly_ttf_gas_data["Average Cost"].append(npy.mean(listof_2022_prices))
    
# create data frame containing average gas prices
yearly_ttf_gas_df = pd.DataFrame(yearly_ttf_gas_data)

# Console output
print("\nOverview:")
print(yearly_ttf_gas_df)

# Plots
yearly_ttf_gas_df.plot.line(x = "Year", y = "Average Cost", title = "Average TTF gas prices since November 2017 in Euros per MWh", figsize=(10,5)).set_ylabel("Euros/MWh")
yearly_ttf_gas_df.plot.bar(x = "Year", y = "Average Cost", title = "Average TTF gas prices since November 2017 in Euros per MWh", figsize=(10,5)).set_ylabel("Euros/MWh")
yearly_ttf_gas_df.plot.hist(x = "Year", title = "Frequency distribution of average TTF gas prices since November 2017 in Euros per MWh", figsize=(10,5)).set_xlabel("Euros/MWh")
# Out:
# Overview:
#    Year  Average Cost
# 0  2017     19.962500
# 1  2018     22.062917
# 2  2019     14.357500
# 3  2020     10.097917
# 4  2021     46.161667
# 5  2022    136.593000
# Text(0.5, 0, 'Euros/MWh')

# %% [markdown]
# <h3>Military Budget vs Gas Prices</h3>
# <p align = "justify">How do NATO and Russian military expenditures compare to the yearly average gas prices in Europe?</p>
#
# <p align = "justify">The correlation for NATO is given below</p>

# %%
# measure the correlation between NATO budget and European gas prices
yearly_ttf_gas_df["Average Cost"].corr(NATO_budget_df.drop([0,1,2])["Cost"])
# Out:
# 0.9911457127038404

# %% [markdown]
# <p align = "justify">and for Russia</p>

# %%
# measure the correlation between Russian military budget and European gas prices
yearly_ttf_gas_df["Average Cost"].corr(RUS_budget_df.drop([0,1,2])["Cost"])
# Out:
# -0.07828369054666177

# %% [markdown]
# <h2>Discussion</h2>
# <p align = "justify">Since 2014, Russia and NATO have exhibited contrasting trends towards military spending. Where NATO has been increasing, Russia has been decreasing steadily. This may be associated with the regime changes of the United States - NATO's single greatest investor. Since 2014, three different American presidents have taken office - Barack Obama, Donald J. Trump, and Joe Biden and each governed under a different mantra. It was the Trump administration, though, who increased American spending towards NATO defense, and the Biden administration who has maintained this trend.</p>
#
# <p align = "justify">NATO defense budget shares a strong positive correlation with the yearly average gas prices of Europe. This implies a sociopolitical relationship between the two quantities, as a result of tensions with Russia, who until September 2022 was the chief supplier of gas to Europe.</p>

# %% [markdown]
# <h2>Hypothesis</h2>
# <p align = "justify">Due to the war-centric relationship between NATO and Russia...</p>
# <div class="alert alert-block alert-success">
# <p align = "justify">decisions by NATO to increase spending have economic repercussions for European members as a direct result of Russian tactics.</p>
# </div>
# <p align = "justify">The economic, environmental, and health related effects of hightened cost in natural gas in Europe may be further explored with other factors taken into consideration, such as</p>
#
# <ul>
#     <li>the cost of living</li>
#     <li>renewable energy usage</li>
#     <li>carbon emissions</li>
#     <li>health issues or deaths due to cold temperatures</li>
# </ul>
#
# <p align = "justify">Although, war has sociological effects, too. The hypothesis that NATO's military budget directly affects Europe's economy (due to her historic dependence on Russian exports) has social parameters which can be investigated under the foundation of these findings:</p>
#
# <ul>
#     <li>anti-Russian sentiment</li>
#     <li>anti-Ukrainian sentiment</li>
#     <li>anti-West sentiment</li>
#     <li>refugees from Eastern Europe</li>
# </ul>
#
# <p align = "justify">For example: European citizens feeling the effects of the war, be they economic or personal, would exhibit political alignment which influences their sentiment. Some people may agree or disagree with the war in Ukraine. Some people may find themselves being highly critical of Russian individuals (Russophobia), even those who are not directly involved with the conflict.</p>

# %% [markdown]
# <h2>Summary</h2>
# <p align = "justify">Using high-level exploratory data analysis, and data downloaded from online sources [1-3], a relationship between defense spending and gas prices from 2017 and 2022 was uncovered. The data used was organized manually into Excel spreadsheets, exported as CSV and then interpreted as data frames with Pandas for analysis.</p>
#
# <p align = "justify">With the strong correlation between NATO budget and gas prices in Europe established, the invitation for deeper analysis on their implications is clear. The next question to answer is: does anti-Russian sentiment correspond to the effects of increased gas prices?</p>
#
# <p align = "justify">This question will be answered in further work, where the technique of <b>sentiment analysis</b> will be applied to classify statements from sources (such as newspaper tabloids, social media, etc) into categories:</p>
#
# <ul>
#     <li>anti-Russian</li>
#     <li>pro-Russian</li>
#     <li>neutral/indifferent</li>
# </ul>
#
# <p align = "justify">These classifications could also be cross-referenced with opinion polls in empirical data gathering. Questionnaires may be applied to gather opinions from individuals about the war.</p>

# %% [markdown]
# <h1>References</h1>
#
# <p align = "justify">[1] NATO, "Defence Expenditures of NATO Countries (2014-2022)", 2022. [Online]. Available: https://www.nato.int/cps/en/natohq/news_197050.htm [Accessed: 26-Oct-2022]</p>
# <p align = "justify">[2] MacroTrends, "Russia Military Spending/Defense Budget 1993-2022", 2022. [Online]. Available: https://www.macrotrends.net/countries/RUS/russia/military-spending-defense-budget [Accessed: 26-Oct-2022]</p>
# <p align = "justify">[3] UK Investing.com, "Dutch TTF Natural Gas Futures - Nov 22 (TFAc1)", 2022. [Online]. Available: https://uk.investing.com/commodities/dutch-ttf-gas-c1-futures-historical-data [Accessed: 27-Oct-2022]</p>
# <p align = "justify">[4] The Jamestown Foundation, Global Research & Analysis, "Russia's Skyrocketing Defense Spending, 2022-2023", 2022. [Online]. Available:  https://jamestown.org/program/russias-skyrocketing-defense-spending-2022-2023/ [Accessed: 28-Oct-2022]</p>
# <p align = "justify">[5] Reuters (P. Polityuk, M. Nichols), "U.N. chief delays travel to try to bring Russia back into Black Sea grain deal", 2022. [Online]. Available: https://www.reuters.com/world/europe/russia-suspends-participation-deal-ukraine-grain-exports-tass-2022-10-29/ [Accessed 30-Oct-2022]</p>
# <p align = "justify">[6] budget.gov.ru., 2022. [Online] Available: http://budget.gov.ru/%D0%91%D1%8E%D0%B4%D0%B6%D0%B5%D1%82/%D0%A0%D0%B0%D1%81%D1%85%D0%BE%D0%B4%D1%8B?message=eyJJTkRNT0JGQl9wYXJhbVBlcmlvZCI6eyJuYW1lIjoiSU5ETU9CRkJfcGFyYW1QZXJpb2QiLCJ2YWx1ZSI6IjIwMjItMDYtMTdUMDA6MDA6MDAuMDAwWiIsInR5cGUiOiJEQVRFIn0sInZpZXdDb2RlIjp7Im5hbWUiOiJ2aWV3Q29kZSIsInZhbHVlIjoiRVBCU18wMDNfMDQ2X3Jl [Accessed: N/A]</p>
